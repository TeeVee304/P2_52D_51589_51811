# %% [markdown]
# #### *ISEL - DEI - LEIM*
# ## Processamento de Imagem e Visão [T52D]
# ### **Trabalho Laboratorial 2A:** Contagem de Veículos emImagens de Vídeo
#
# Ricardo Faria ($51589$),
# Bruno Pereira ($51811$)
#
# **Docentes responsáveis:**
# - Prof. João Pedro Costa
# - Prof. Pedro Mendes Jorge

# %%
import numpy as np
from lib.pipeline import Pipeline
import argparse
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[82], line 2
#       1 import numpy as np
# ----> 2 from lib.pipeline import Pipeline
#       3 import argparse
#
# File c:\Users\bruno\OneDrive\Documentos\GitHub\P2_52D_51589_A51811\src\lib\pipeline.py:1
# ----> 1 from lib.background import BackgroundExtractor
#       2 from lib.motion import MotionDetector
#       3 from lib.tracker import VehicleTracker
#
# ImportError: cannot import name 'BackgroundExtractor' from 'lib.background' (c:\Users\bruno\OneDrive\Documentos\GitHub\P2_52D_51589_A51811\src\lib\background.py)

# %%
def parse_roi(s: str) -> np.ndarray:
    # string like: "x1,y1 x2,y2 x3,y3"
    parts = s.strip().split()
    pts = []
    for p in parts:
        x,y = p.split(',')
        pts.append([int(x), int(y)])
    return np.array(pts, dtype=np.int32)

# %%
parser = argparse.ArgumentParser()
    parser.add_argument('--input', required=True)
    parser.add_argument('--output', required=True)
    parser.add_argument('--roi', required=False, help='"x1,y1 x2,y2 ..."')
    parser.add_argument('--mode', choices=['median','mog2'], default='median')
    parser.add_argument('--scale', type=float, default=0.02, help='metros por pixel')
    parser.add_argument('--min_area', type=int, default=500)
    args = parser.parse_args()

    logging.basicConfig(level=logging.INFO, format='%(asctime)s %(levelname)s %(message)s')

    if args.roi:
        roi_poly = parse_roi(args.roi)
    else:
        roi_poly = None

    pipe = Pipeline(input_path=args.input, output_path=args.output, roi_polygon=roi_poly,
                    scale_m_per_px=args.scale, min_area=args.min_area)
    pipe.run(mode=args.mode)

# %%
video_path = "resources/AutoEstrada.avi"
roi_polygon = np.array([
    [95, 85],    # Canto Superior Esquerdo
    [160, 85],    # Canto Superior Direito
    [225, 240],   # Canto Inferior Direito
    [5, 240]      # Canto Inferior Esquerdo
], dtype=np.int32)

detect_cars(video_path, "cars_detected.mp4", roi_polygon)
# Out:
# A processar: resources/AutoEstrada.avi
# Resolução: 320x240, FPS: 23.97
# Frames processados: 100
# Frames processados: 200
# Processamento concluído. Total de frames: 234
# Vídeo salvo em: cars_detected.mp4
