# %% [markdown]
# #### *ISEL - DEI - LEIM*
# ## Processamento de Imagem e Visão [T52D]
# ### **Trabalho Laboratorial 2A:** Contagem de Veículos emImagens de Vídeo
#
# Ricardo Faria ($51589$),
# Bruno Pereira ($51811$)
#
# **Docentes responsáveis:**
# - Prof. João Pedro Costa
# - Prof. Pedro Mendes Jorge

# %%
import numpy as np
from lib.pipeline import Pipeline

# %%
roi_polygon = np.array([
    [95, 85],    # Canto Superior Esquerdo
    [160, 85],    # Canto Superior Direito
    [225, 240],   # Canto Inferior Direito
    [5, 240]      # Canto Inferior Esquerdo
], dtype=np.int32)

pipeline = Pipeline(
    input_path="resources/AutoEstrada.avi",
    output_path="cars_detected.mp4",
    roi_polygon=roi_polygon,
    m_per_px=0.02,
    min_area=500
)

pipeline.run()
# Out:
# Construindo background...
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[4], line 16
#       1 roi_polygon = np.array([
#       2     [95, 85],    # Canto Superior Esquerdo
#       3     [160, 85],    # Canto Superior Direito
#       4     [225, 240],   # Canto Inferior Direito
#       5     [5, 240]      # Canto Inferior Esquerdo
#       6 ], dtype=np.int32)
#       8 pipeline = Pipeline(
#       9     input_path="resources/AutoEstrada.avi",
#      10     output_path="cars_detected.mp4",
#    (...)
#      13     min_area=500
#      14 )
# ---> 16 pipeline.run()
#
# File c:\Users\bruno\OneDrive\Documentos\GitHub\P2_52D_51589_A51811\src\lib\pipeline.py:105, in Pipeline.run(self)
#     102     cropped = frame
#     103     roi_mask = None
# --> 105 result = self.detector.detect(cropped)
#     106 detections = {'contours': result['contours'], 'bboxes': result['bboxes']}
#     107 binary = result['binary']
#
# File c:\Users\bruno\OneDrive\Documentos\GitHub\P2_52D_51589_A51811\src\lib\motion.py:69, in MotionDetector.detect(self, frame)
#      64 def detect(self, frame):
#      65     """
#      66     Detecta regiões de movimento em um único frame.
#      67     Retorna contornos e bounding boxes.
#      68     """
# ---> 69     gray = self._subtract_background(frame)
#      70     binary = self._threshold_image(gray)
#      71     contours = self._find_contours(binary)
#
# File c:\Users\bruno\OneDrive\Documentos\GitHub\P2_52D_51589_A51811\src\lib\motion.py:25, in MotionDetector._subtract_background(self, frame)
#      17 def _subtract_background(self, frame):
#      18     """
#      19     Subtrai o fundo (background) de um frame, aplicando uma máscara de ROI caso seja fornecida.
#      20     Args:
#    (...)
#      23         np.ndarray: Imagem grayscale resultante da subtração do fundo.
#      24     """
# ---> 25     diff = cv.absdiff(frame, self.background)
#      26     gray = cv.cvtColor(diff, cv.COLOR_BGR2GRAY)
#      27     if self._roi_mask is not None:
#
# error: OpenCV(4.11.0) D:\a\opencv-python\opencv-python\opencv\modules\core\src\arithm.cpp:665: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and the same number of channels), nor 'array op scalar', nor 'scalar op array' in function 'cv::arithm_op'
