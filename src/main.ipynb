# %% [markdown]
# #### *ISEL - DEI - LEIM*
# ## Processamento de Imagem e Visão [T52D]
# ### **Trabalho Laboratorial 2A:** Contagem de Veículos emImagens de Vídeo
#
# Ricardo Faria ($51589$),
# Bruno Pereira ($51811$)
#
# **Docentes responsáveis:**
# - Prof. João Pedro Costa
# - Prof. Pedro Mendes Jorge

# %%
import numpy as np
from lib.pipeline import Pipeline

# %%
roi_polygon = np.array([
    [95, 85],    # Canto Superior Esquerdo
    [160, 85],    # Canto Superior Direito
    [225, 240],   # Canto Inferior Direito
    [5, 240]      # Canto Inferior Esquerdo
], dtype=np.int32)

pipeline = Pipeline(
    input_path="resources/AutoEstrada.avi",
    output_path="cars_detected.mp4",
    roi_polygon=roi_polygon,
    m_per_px=0.02,
    min_area=500
)

pipeline.run()
# Out:
# Construindo background...
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[2], line 16
#       1 roi_polygon = np.array([
#       2     [95, 85],    # Canto Superior Esquerdo
#       3     [160, 85],    # Canto Superior Direito
#       4     [225, 240],   # Canto Inferior Direito
#       5     [5, 240]      # Canto Inferior Esquerdo
#       6 ], dtype=np.int32)
#       8 pipeline = Pipeline(
#       9     input_path="resources/AutoEstrada.avi",
#      10     output_path="cars_detected.mp4",
#    (...)
#      13     min_area=500
#      14 )
# ---> 16 pipeline.run()
#
# File c:\Users\bruno\OneDrive\Documentos\GitHub\P2_52D_51589_A51811\src\lib\pipeline.py:105, in Pipeline.run(self)
#     102     cropped = frame
#     103     roi_mask = None
# --> 105 detections = self.detector.detect(frame)
#     107 # convert detections coords back to full frame
#     108 if roi_bbox is not None:
#
# File c:\Users\bruno\OneDrive\Documentos\GitHub\P2_52D_51589_A51811\src\lib\motion.py:93, in MotionDetector.detect(self, frame)
#      88 def detect(self, frame):
#      89     """
#      90     Detecta regiões de movimento num único frame.
#      91     Retorna contornos e bounding boxes.
#      92     """
# ---> 93     frame_proc = self._apply_roi(frame)
#      95     # inicializa background no MESMO TAMANHO e FORMATO do frame_proc
#      96     if self.background is None:
#
# File c:\Users\bruno\OneDrive\Documentos\GitHub\P2_52D_51589_A51811\src\lib\motion.py:27, in MotionDetector._apply_roi(self, frame)
#      25 if self.roi_mask is None:
#      26     return frame
# ---> 27 return cv.bitwise_and(frame, frame, mask=self.roi_mask)
#
# error: OpenCV(4.11.0) D:\a\opencv-python\opencv-python\opencv\modules\core\src\arithm.cpp:230: error: (-215:Assertion failed) (mtype == CV_8U || mtype == CV_8S) && _mask.sameSize(*psrc1) in function 'cv::binary_op'
